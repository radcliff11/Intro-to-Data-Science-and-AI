# %% [markdown]
# Done:
# ### Identify 6 strongest predictors of Happiness (done with heatmap)
#
# ### Build different Regression Models and check their features
# #Done with RF, XGB, NN, tune RF to improve
# regularize NN
# spot features using RF
#
# ### Cluster and see what are the significances
# The most distinct Clusters
# Cluster 0: Countries w ....
# Cluster 1: Countries w ....
#
# ### Identify the anomalies
# {
#
# 1. Countries score high on Big 6 but not happy
# (Jordan - El Savador) (Peru - Brazil) (Libya - Nepal)
# (Anomaly #1 file)
# 2. Countries that are happy but score low on the big 6
# (Anomaly #2 file)
#
# }
#
#
# On Going:
# ### Geographic Analysis
# plotly on GDP (population weighted) - bubble graph

# %% [markdown]
# Task 0 - Import All Dependencies

# %% [markdown]
# https://www.researchgate.net/post/How_do_I_choose_the_best_clustering_approach

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sb
sb.set()

# %%
 

import warnings 
warnings.filterwarnings('ignore')
warnings.filterwarnings('ignore', category=DeprecationWarning)

# %% [markdown]
# **Part I. Data Handling and Exploration**

# %%
# !python untitled2.py

# %%
from untitled2 import *

# %%
accuracy
# Out:
#            LinReg train  Linreg test  RF train   RF test  Boosted RF train  \
# R Squared      0.750467     0.780304  0.937470  0.743642          0.962039
# MSE            0.301568     0.297065  0.075570  0.346639          0.045877
# MAE            0.440002     0.432311  0.183437  0.445026          0.165161
#
#            Boosted RF test  XGB train  XGB test
# R Squared         0.807656   0.985800  0.782807
# MSE               0.260081   0.017161  0.293680
# MAE               0.380928   0.094077  0.422220

# %%
#just testing
#c2,d2 = evaluate_model(boostedRF,x_train,x_test,y_train,y_test)

# %%
# !python untitled4.py

# %%
from untitled4 import *

# %%
#change in happiness?
#what gov shld change to change happiness

# %%
gmm_labels
# Out:
# array([2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 4, 2, 2, 2, 2, 4, 4, 2, 2, 2, 2,
#        4, 0, 6, 4, 9, 4, 2, 6, 4, 0, 6, 4, 6, 0, 9, 0, 4, 9, 7, 0, 2, 6,
#        6, 0, 4, 4, 2, 4, 6, 0, 0, 4, 9, 0, 6, 9, 4, 5, 6, 2, 0, 7, 7, 6,
#        0, 0, 6, 7, 6, 0, 1, 9, 4, 6, 6, 3, 0, 0, 0, 7, 0, 4, 6, 2, 0, 4,
#        7, 0, 4, 8, 3, 1, 8, 8, 0, 5, 8, 7, 0, 5, 1, 8, 4, 6, 5, 8, 5, 3,
#        1, 5, 7, 6, 5, 8, 8, 0, 6, 8, 6, 0, 8, 5, 5, 0, 3, 5, 7, 8, 1, 7,
#        1, 1, 5, 3, 1, 5, 1, 8, 1])

# %%
# Summary of the Cluster Labels
f,axes = plt.subplots(1,2,figsize = (16,8))
sb.countplot(labeled_kmeans_pp_df["Cluster"], ax = axes[0])
sb.countplot(labeled_gmm_df["Cluster"], ax = axes[1])

# %%
# !python login.py
# Out:
# Traceback (most recent call last):
#   File "login.py", line 8, in <module>
#     import bcrypt
# ModuleNotFoundError: No module named 'bcrypt'

# %%
import bcrypt
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-2-c2a86f184093> in <module>()
# ----> 1 import bcrypt
#
# ModuleNotFoundError: No module named 'bcrypt'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------
